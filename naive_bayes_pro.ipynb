# %% [markdown]
# https://github.com/YouAITube

# %%
from sklearn.naive_bayes import GaussianNB, CategoricalNB
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_openml
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler

# Load dataset (using some data with both numerical and categorical features)
data = fetch_openml("adult", version=2, as_frame=True)
X = data['data']
y = (data['target'] == '>50K').astype(int)

display(X)
display(y)
# Out:
#        age     workclass  fnlwgt     education  education-num  \
# 0       25       Private  226802          11th              7
# 1       38       Private   89814       HS-grad              9
# 2       28     Local-gov  336951    Assoc-acdm             12
# 3       44       Private  160323  Some-college             10
# 4       18           NaN  103497  Some-college             10
# ...    ...           ...     ...           ...            ...
# 48837   27       Private  257302    Assoc-acdm             12
# 48838   40       Private  154374       HS-grad              9
# 48839   58       Private  151910       HS-grad              9
# 48840   22       Private  201490       HS-grad              9
# 48841   52  Self-emp-inc  287927       HS-grad              9
#
#            marital-status         occupation relationship   race     sex  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing      Husband  White    Male
# 2      Married-civ-spouse    Protective-serv      Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct      Husband  Black    Male
# 4           Never-married                NaN    Own-child  White  Female
# ...                   ...                ...          ...    ...     ...
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country
# 0                 0             0              40  United-States
# 1                 0             0              50  United-States
# 2                 0             0              40  United-States
# 3              7688             0              40  United-States
# 4                 0             0              30  United-States
# ...             ...           ...             ...            ...
# 48837             0             0              38  United-States
# 48838             0             0              40  United-States
# 48839             0             0              40  United-States
# 48840             0             0              20  United-States
# 48841         15024             0              40  United-States
#
# [48842 rows x 14 columns]
# 0        0
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 48837    0
# 48838    1
# 48839    0
# 48840    0
# 48841    1
# Name: class, Length: 48842, dtype: int64

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       46043 non-null  category
#  2   fnlwgt          48842 non-null  int64
#  3   education       48842 non-null  category
#  4   education-num   48842 non-null  int64
#  5   marital-status  48842 non-null  category
#  6   occupation      46033 non-null  category
#  7   relationship    48842 non-null  category
#  8   race            48842 non-null  category
#  9   sex             48842 non-null  category
#  10  capital-gain    48842 non-null  int64
#  11  capital-loss    48842 non-null  int64
#  12  hours-per-week  48842 non-null  int64
#  13  native-country  47985 non-null  category
# dtypes: category(8), int64(6)
# memory usage: 2.6 MB

# %%
# Separate numerical and categorical features
num_features = X.select_dtypes(include=['float64',
                                        'int64']).columns.tolist()
cat_features = X.select_dtypes(include=['category',
                                        'object']).columns.tolist()

display(num_features)
# Out:
# ['age',
#  'fnlwgt',
#  'education-num',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week']

# %%
X[num_features]
# Out:
#        age  fnlwgt  education-num  capital-gain  capital-loss  hours-per-week
# 0       25  226802              7             0             0              40
# 1       38   89814              9             0             0              50
# 2       28  336951             12             0             0              40
# 3       44  160323             10          7688             0              40
# 4       18  103497             10             0             0              30
# ...    ...     ...            ...           ...           ...             ...
# 48837   27  257302             12             0             0              38
# 48838   40  154374              9             0             0              40
# 48839   58  151910              9             0             0              40
# 48840   22  201490              9             0             0              20
# 48841   52  287927              9         15024             0              40
#
# [48842 rows x 6 columns]

# %%
# Split the dataset into train and test
X_train, X_test, y_train, y_test = train_test_split(X[num_features],
                                                    y,
                                                    test_size=0.2, random_state=42)

# %%
GNB = GaussianNB()

GNB.fit(X_train, y_train)

y_predict=GNB.predict(X_test)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score as accuracy
from sklearn.metrics import f1_score as f1

print('ACC: %.4f' % accuracy(y_predict,y_test))
print('F1 : %.4f' %  f1(y_predict,y_test, average = 'macro'))

print (classification_report(y_test, y_predict))
# Out:
# ACC: 0.7992
# F1 : 0.6491
#               precision    recall  f1-score   support
#
#            0       0.82      0.95      0.88      7479
#            1       0.65      0.31      0.42      2290
#
#     accuracy                           0.80      9769
#    macro avg       0.73      0.63      0.65      9769
# weighted avg       0.78      0.80      0.77      9769

# %% [markdown]
# what is the class balance (a priori probability)

# %%
GNB.class_prior_
# Out:
# array([0.75950145, 0.24049855])

# %% [markdown]
# probability answer

# %%
import pandas as pd
import seaborn as sns
pd.DataFrame(GNB.predict_proba(X_test)).style.background_gradient(cmap=sns.color_palette("vlag", as_cmap=True) ,
                                        vmin = 0,
                                        vmax = 1
                                        ).format(precision=4)
# Out:
# <style type="text/css">
# #T_0b85f_row0_col0, #T_0b85f_row12_col0, #T_0b85f_row14_col0, #T_0b85f_row18_col0, #T_0b85f_row40_col0, #T_0b85f_row42_col0, #T_0b85f_row58_col0, #T_0b85f_row60_col0, #T_0b85f_row75_col0, #T_0b85f_row77_col0, #T_0b85f_row85_col0, #T_0b85f_row89_col0, #T_0b85f_row92_col0, #T_0b85f_row95_col0, #T_0b85f_row108_col0, #T_0b85f_row114_col0, #T_0b85f_row122_col0, #T_0b85f_row139_col0, #T_0b85f_row141_col0, #T_0b85f_row159_col0, #T_0b85f_row173_col0, #T_0b85f_row192_col0, #T_0b85f_row199_col0, #T_0b85f_row202_col0, #T_0b85f_row204_col0, #T_0b85f_row212_col0, #T_0b85f_row222_col0, #T_0b85f_row223_col0, #T_0b85f_row226_col0, #T_0b85f_row241_col0, #T_0b85f_row246_col0, #T_0b85f_row250_col0, #T_0b85f_row253_col0, #T_0b85f_row255_col0, #T_0b85f_row268_col0, #T_0b85f_row274_col0, #T_0b85f_row294_col0, #T_0b85f_row297_col0, #T_0b85f_row298_col0, #T_0b85f_row300_col0, #T_0b85f_row314_col0, #T_0b85f_row316_col0, #T_0b85f_row321_col0, #T_0b85f_row324_col0, #T_0b85f_row333_col0, #T_0b85f_row334_col0, #T_0b85f_row340_col0, #T_0b85f_row343_col0, #T_0b85f_row345_col0, #T_0b85f_row346_col0, #T_0b85f_row367_col0, #T_0b85f_row369_col0, #T_0b85f_row370_col0, #T_0b85f_row372_col0, #T_0b85f_row375_col0, #T_0b85f_row380_col0, #T_0b85f_row405_col0, #T_0b85f_row411_col0, #T_0b85f_row421_col0, #T_0b85f_row448_col0, #T_0b85f_row451_col0, #T_0b85f_row453_col0, #T_0b85f_row457_col0, #T_0b85f_row458_col0, #T_0b85f_row464_col0, #T_0b85f_row474_col0, #T_0b85f_row478_col0, #T_0b85f_row509_col0, #T_0b85f_row519_col0, #T_0b85f_row522_col0, #T_0b85f_row525_col0, #T_0b85f_row535_col0, #T_0b85f_row549_col0, #T_0b85f_row553_col0, #T_0b85f_row564_col0, #T_0b85f_row569_col0, #T_0b85f_row571_col0, #T_0b85f_row572_col0, #T_0b85f_row580_col0, #T_0b85f_row588_col0, #T_0b85f_row590_col0, #T_0b85f_row598_col0, #T_0b85f_row603_col0, #T_0b85f_row613_col0, #T_0b85f_row633_col0, #T_0b85f_row634_col0, #T_0b85f_row660_col0, #T_0b85f_row661_col0, #T_0b85f_row675_col0, #T_0b85f_row679_col0, #T_0b85f_row690_col0, #T_0b85f_row708_col0, #T_0b85f_row710_col0, #T_0b85f_row713_col0, #T_0b85f_row731_col0, #T_0b85f_row732_col0, #T_0b85f_row738_col0, #T_0b85f_row755_col0, #T_0b85f_row759_col0, #T_0b85f_row761_col0, #T_0b85f_row778_col0, #T_0b85f_row779_col0, #T_0b85f_row787_col0, #T_0b85f_row794_col0, #T_0b85f_row799_col0, #T_0b85f_row814_col0, #T_0b85f_row819_col0, #T_0b85f_row822_col0, #T_0b85f_row825_col0, #T_0b85f_row826_col0, #T_0b85f_row831_col0, #T_0b85f_row835_col0, #T_0b85f_row836_col0, #T_0b85f_row840_col0, #T_0b85f_row841_col0, #T_0b85f_row843_col0, #T_0b85f_row844_col0, #T_0b85f_row845_col0, #T_0b85f_row846_col0, #T_0b85f_row852_col0, #T_0b85f_row864_col0, #T_0b85f_row865_col0, #T_0b85f_row866_col0, #T_0b85f_row871_col0, #T_0b85f_row875_col0, #T_0b85f_row884_col0, #T_0b85f_row908_col0, #T_0b85f_row917_col0, #T_0b85f_row925_col0, #T_0b85f_row931_col0, #T_0b85f_row943_col0, #T_0b85f_row961_col0, #T_0b85f_row967_col0, #T_0b85f_row976_col0, #T_0b85f_row984_col0, #T_0b85f_row985_col0, #T_0b85f_row1015_col0, #T_0b85f_row1045_col0, #T_0b85f_row1049_col0, #T_0b85f_row1055_col0, #T_0b85f_row1056_col0, #T_0b85f_row1058_col0, #T_0b85f_row1072_col0, #T_0b85f_row1074_col0, #T_0b85f_row1081_col0, #T_0b85f_row1082_col0, #T_0b85f_row1083_col0, #T_0b85f_row1090_col0, #T_0b85f_row1096_col0, #T_0b85f_row1098_col0, #T_0b85f_row1107_col0, #T_0b85f_row1113_col0, #T_0b85f_row1122_col0, #T_0b85f_row1127_col0, #T_0b85f_row1128_col0, #T_0b85f_row1132_col0, #T_0b85f_row1136_col0, #T_0b85f_row1143_col0, #T_0b85f_row1152_col0, #T_0b85f_row1154_col0, #T_0b85f_row1156_col0, #T_0b85f_row1194_col0, #T_0b85f_row1195_col0, #T_0b85f_row1199_col1, #T_0b85f_row1206_col0, #T_0b85f_row1213_col0, #T_0b85f_row1216_col0, #T_0b85f_row1222_col0, #T_0b85f_row1225_col0, #T_0b85f_row1226_col0, #T_0b85f_row1232_col0, #T_0b85f_row1233_col0, #T_0b85f_row1244_col0, #T_0b85f_row1249_col0, #T_0b85f_row1255_col0, #T_0b85f_row1265_col0, #T_0b85f_row1280_col0, #T_0b85f_row1286_col0, #T_0b85f_row1296_col0, #T_0b85f_row1301_col0, #T_0b85f_ro ...

# %% [markdown]
# count groupby agg mean std

# %%
pd.DataFrame(GNB.theta_, columns = X[num_features].columns)
# Out:
#          age         fnlwgt  education-num  capital-gain  capital-loss  \
# 0  36.823561  189943.038347       9.593982    146.909860     54.770454
# 1  44.302756  188675.924018      11.601256   3999.263488    198.124508
#
#    hours-per-week
# 0       38.838051
# 1       45.449824

# %%
pd.DataFrame(GNB.var_, columns = X[num_features].columns)
# Out:
#           age        fnlwgt  education-num  capital-gain   capital-loss  \
# 0  210.262758  1.130350e+10      17.064440  8.623595e+05   98757.610587
# 1  122.807428  1.049730e+10      16.744136  2.155865e+08  358538.770892
#
#    hours-per-week
# 0      165.656123
# 1      135.151573
